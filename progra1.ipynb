# %% [markdown]
# <html><body><body>
# <h1 style="color: blue"> Hassan </h1>
# <h2 style="color: green"; font-family: verdana; font-size:900%> Ph: 0300000000</h2>
# <h3 style="color: yellow">email: ABC@gmail.com</h3>
# </body> </body></html>

# %%
#install library
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 750.3 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/11.5 MB 750.3 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/11.5 MB 766.5 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/11.5 MB 766.5 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/11.5 MB 714.7 kB/s eta 0:00:15
#    --- ------------------------------------ 1.0/11.5 MB 714.7 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/11.5 MB 669.2 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/11.5 MB 669.2 kB/s eta 0:00:16
# ...

# %%
import pandas
import pandas as pd

# %%
pd.read_csv("data.csv")
# Out:
#        month        Day   Marks  Pysics  Math  english  total
# 0     january     Monday    NaN      23    55       34    112
# 1    february    Tuesday    NaN      56    64       22    142
# 2       march  Wednesday    NaN      54    55       33    142
# 3       april   Thursday    NaN      56    45       22    123
# 4         may     Friday    NaN      34    44        5     83
# 5        june   Saturday    NaN      33    33       24     90
# 6        july     Sunday    NaN      33     4        3     40
# 7      august     Monday    NaN      22    34       54    110
# 8   september    Tuesday    NaN      46    63        5    114
# 9     october  Wednesday    NaN      36    46        2     84
# 10   november   Thursday    NaN      14    24        5     43
# 11   december     Friday    NaN      35    72        2    109

# %%
df=pd.data_csv("data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.data_csv("data.csv")
#       2 print(df)
#
# AttributeError: module 'pandas' has no attribute 'data_csv'

# %%
df=pd.read+csv("data.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.read+csv("data.csv")
#       2 print(df)
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df= pd.read_csv("data.csv")
print(df)
# Out:
#        month        Day   Marks  Pysics  Math  english  total
# 0     january     Monday    NaN      23    55       34    112
# 1    february    Tuesday    NaN      56    64       22    142
# 2       march  Wednesday    NaN      54    55       33    142
# 3       april   Thursday    NaN      56    45       22    123
# 4         may     Friday    NaN      34    44        5     83
# 5        june   Saturday    NaN      33    33       24     90
# 6        july     Sunday    NaN      33     4        3     40
# 7      august     Monday    NaN      22    34       54    110
# 8   september    Tuesday    NaN      46    63        5    114
# 9     october  Wednesday    NaN      36    46        2     84
# 10   november   Thursday    NaN      14    24        5     43
# 11   december     Friday    NaN      35    72        2    109

# %%
def head
# Out:
#   Cell In[8], line 1
#     def head
#             ^
# SyntaxError: expected '('

# %%
# %pip install pandas openpyxlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement openpyxlib (from versions: none)
# ERROR: No matching distribution found for openpyxlib

# %%
df=pd.read_excel("data.xlsx")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pd.read_excel("data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
exc=pd.read_excel("data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\hassa\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
# %pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel("data.xlsx")

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.read_excel("data.xlsx")

# %%
print(df)
# Out:
#        month        Day   Marks  Pysics  Math  english  total
# 0     january     Monday    NaN      23    55       34    112
# 1    february    Tuesday    NaN      56    64       22    142
# 2       march  Wednesday    NaN      54    55       33    142
# 3       april   Thursday    NaN      56    45       22    123
# 4         may     Friday    NaN      34    44        5     83
# 5        june   Saturday    NaN      33    33       24     90
# 6        july     Sunday    NaN      33     4        3     40
# 7      august     Monday    NaN      22    34       54    110
# 8   september    Tuesday    NaN      46    63        5    114
# 9     october  Wednesday    NaN      36    46        2     84
# 10   november   Thursday    NaN      14    24        5     43
# 11   december     Friday    NaN      35    72        2    109

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.read_csv("")
